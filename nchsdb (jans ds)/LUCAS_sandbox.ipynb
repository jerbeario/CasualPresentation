# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %%
# !PWD
# Out:
# /Users/jeremypalmerio/Repos/CasualPresentation

# %%
fname = 'nchsdb (jans ds)/data/selected_cols.csv'
df = pd.read_csv(fname, sep=',')

# %%
df
# Out:
#      subs_alc_1  subs_tob_1  socialjetlag    msfsc1  mh_anx  mh_health  \
# 0             1           0         -32.4  1.375000       1          2
# 1             3           3          67.5  1.197917       2          1
# 2             2           3          60.0  1.152083       2          3
# 3             2           3          60.0  1.000000       2          4
# 4             2           0         342.5  1.240575       1          1
# ..          ...         ...           ...       ...     ...        ...
# 939           0           0          90.0  0.979167       0          3
# 940           2           0          45.0  1.122272       2          2
# 941           1           0         -30.0  1.113095       2          1
# 942           4           2         -97.5  1.170387       0          3
# 943           2           1         122.5  1.381944       0          3
#
#      mh_mdd  education  income    age  orientation  race  sex  transgender
# 0         1          0       1  18.75            0     0    0            0
# 1         2          0      -1  19.74            1     1    0            0
# 2         2          0       0  27.33            1     0    0            0
# 3         2          1      -1  29.60            0     0    0            0
# 4        -1          0       2  26.71            0     0    0            0
# ..      ...        ...     ...    ...          ...   ...  ...          ...
# 939      -1          0       0  19.15            0     2    0            0
# 940       2          0       0  22.07            0     0    0            0
# 941       0          0       0  19.62            0     0    0            0
# 942       0          0       3  19.50            0     4    0            1
# 943       0          0       0  21.84            0     1    1            0
#
# [944 rows x 14 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   subs_alc_1    944 non-null    int64
#  1   subs_tob_1    944 non-null    int64
#  2   socialjetlag  944 non-null    float64
#  3   msfsc1        944 non-null    float64
#  4   mh_anx        944 non-null    int64
#  5   mh_health     944 non-null    int64
#  6   mh_mdd        944 non-null    int64
#  7   education     944 non-null    int64
#  8   income        944 non-null    int64
#  9   age           944 non-null    float64
#  10  orientation   944 non-null    int64
#  11  race          944 non-null    int64
#  12  sex           944 non-null    int64
#  13  transgender   944 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 103.4 KB

# %%
df.describe()
# Out:
#        subs_alc_1  subs_tob_1  socialjetlag      msfsc1      mh_anx  \
# count  944.000000  944.000000    944.000000  944.000000  944.000000
# mean     1.269068    0.407839     62.025900    1.186933    0.545551
# std      1.171261    0.884641     71.191852    0.103639    1.021529
# min      0.000000    0.000000   -330.000000    0.861111   -1.000000
# 25%      0.000000    0.000000     24.750000    1.127778    0.000000
# 50%      1.000000    0.000000     60.000000    1.203249    0.000000
# 75%      2.000000    0.000000     95.000000    1.257775    1.000000
# max      5.000000    3.000000    410.000000    1.572917    2.000000
#
#         mh_health      mh_mdd   education      income         age  \
# count  944.000000  944.000000  944.000000  944.000000  944.000000
# mean     2.562500    0.355932    0.075212    0.070975   20.569386
# std      0.947348    0.965144    0.263873    1.030934    4.083705
# min      0.000000   -1.000000    0.000000   -1.000000   18.010000
# 25%      2.000000    0.000000    0.000000    0.000000   18.780000
# 50%      3.000000    0.000000    0.000000    0.000000   19.360000
# 75%      3.000000    1.000000    0.000000    0.000000   20.532500
# max      4.000000    2.000000    1.000000    4.000000   52.690000
#
#        orientation        race        sex  transgender
# count   944.000000  944.000000  944.00000   944.000000
# mean      0.226695    0.514831    0.26589     0.026483
# std       0.550221    1.086792    0.44204     0.160652
# min       0.000000    0.000000    0.00000     0.000000
# 25%       0.000000    0.000000    0.00000     0.000000
# 50%       0.000000    0.000000    0.00000     0.000000
# 75%       0.000000    0.000000    1.00000     0.000000
# max       3.000000    5.000000    1.00000     1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ### Making the Graph

# %%
G = nx.DiGraph()
G.add_nodes_from(df.columns)
G.add_edges_from([('Anxiety', 'Smoking'),
                   ('Peer_Pressure', 'Smoking'),
                   ('Smoking', 'Yellow_Fingers'),
                   ('Smoking', 'Lung_cancer'),
                   ('Genetics', 'Lung_cancer'),
                   ('Genetics', 'Attention_Disorder'),
                   ('Lung_cancer', 'Fatigue'),
                   ('Lung_cancer', 'Coughing'),
                   ('Allergy', 'Coughing'),
                   ('Coughing', 'Fatigue'),
                   ('Attention_Disorder', 'Car_Accident'),
                   ('Fatigue', 'Car_Accident'),

                     ])
plt.figure(figsize=(12,12))

nx.draw_shell(G, with_labels=True, node_color = ['w', 'w', 'r', 'w', 'w', 'w', 'w', 'r', 'w', 'w', 'w', 'w'], arrowsize = 50, node_size = 10000, edgecolors='black', font_size=12)

# %%
nx.write_gml(G, 'LUCAS.gml')

# %% [markdown]
# ## Estimands

# %%
from dowhy.causal_identifier import backdoor
from dowhy import CausalModel

# %%
# a utility function to parse the .gml file to string 
# From tutorial 3
def gml_to_string(file):
    gml_str = ''
    with open(file, 'r') as file:
        for line in file:
            gml_str += line.rstrip()
    return gml_str

# %%
graph_str = gml_to_string('LUCAS.gml')

model=CausalModel(
    data = df,
    treatment='Anxiety',
    outcome='Car_Accident',
    graph=graph_str
)
model.view_model()

# %%
identified_estimand = model.identify_effect()
print(identified_estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#     d
# ──────────(E[Car_Accident])
# d[Anxiety]
# Estimand assumption 1, Unconfoundedness: If U→{Anxiety} and U→Car_Accident then P(Car_Accident|Anxiety,,U) = P(Car_Accident|Anxiety,)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# Estimand expression:
#  ⎡            d                                ∂                               ↪
# E⎢──────────────────────────(Car_Accident)⋅──────────([Yellow_Fingers  Smoking ↪
#  ⎣d[Yellow_Fingers  Smoking]               ∂[Anxiety]                          ↪
#
# ↪   ⎤
# ↪ ])⎥
# ↪   ⎦
# Estimand assumption 1, Full-mediation: Yellow_Fingers,Smoking intercepts (blocks) all directed paths from Anxiety to C,a,r,_,A,c,c,i,d,e,n,t.
# Estimand assumption 2, First-stage-unconfoundedness: If U→{Anxiety} and U→{Yellow_Fingers,Smoking} then P(Yellow_Fingers,Smoking|Anxiety,U) = P(Yellow_Fingers,Smoking|Anxiety)
# Estimand assumption 3, Second-stage-unconfoundedness: If U→{Yellow_Fingers,Smoking} and U→Car_Accident then P(Car_Accident|Yellow_Fingers,Smoking, Anxiety, U) = P(Car_Accident|Yellow_Fingers,Smoking, Anxiety)

# %%
identifier = model.identifier
identifier.identify_backdoor(model._graph._graph, model._treatment, model._outcome, list(model._graph.get_all_nodes(include_unobserved=False)))
# Out:
# [{'backdoor_set': set()},
#  {'backdoor_set': ('Allergy',
#    'Peer_Pressure',
#    'Genetics',
#    'Attention_Disorder')},
#  {'backdoor_set': ('Allergy',)},
#  {'backdoor_set': ('Peer_Pressure',)},
#  {'backdoor_set': ('Genetics',)},
#  {'backdoor_set': ('Attention_Disorder',)}]

# %% [markdown]
# ## Estimating Causal Effect

# %%
from sklearn.linear_model import LinearRegression

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")
print(causal_estimate)
print("Causal Estimate is " + str(causal_estimate.value))
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#     d
# ──────────(E[Car_Accident])
# d[Anxiety]
# Estimand assumption 1, Unconfoundedness: If U→{Anxiety} and U→Car_Accident then P(Car_Accident|Anxiety,,U) = P(Car_Accident|Anxiety,)
#
# ## Realized estimand
# b: Car_Accident~Anxiety+Anxiety*Genetics+Anxiety*Peer_Pressure+Anxiety*Allergy+Anxiety*Attention_Disorder
# Target units:
#
# ## Estimate
# Mean value: 0.029664433911190446
# ### Conditional Estimates
# __categorical__Genetics  __categorical__Peer_Pressure  __categorical__Allergy  __categorical__Attention_Disorder
# (-0.001, 1.0]            (-0.001, 1.0]                 (-0.001, 1.0]           (-0.001, 1.0]                        0.029664
# dtype: float64
# Causal Estimate is 0.029664433911190446
# /Users/jeremypalmerio/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_estimator.py:266: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   by_effect_mods = data.groupby(effect_modifier_names)
# /Users/jeremypalmerio/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]
# /Users/jeremypalmerio/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_estimators/regression_estimator.py:131: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept_parameter = self.model.params[0]

# %%
# using the backdoor adjustment set and propensity score stratification
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="iv.instrumental_variable")
print(causal_estimate)
print("Causal Estimate is " + str(causal_estimate.value))
# Out:
# Estimation failed! No relevant identified estimand available for this estimation method.
# Causal Estimate is None

# %% [markdown]
# ## Causal Discovery

# %% [markdown]
# ### PC algorithm

# %%
from pgmpy.estimators import PC, ExpertKnowledge
from dowhy import CausalModel

# %%
alpha = 0.05
pc = PC(df)
pc_graph = pc.estimate(ci_test='pillai', return_type='cpdag', significance_level=alpha)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'subs_alc_1': 'N', 'subs_tob_1': 'N', 'socialjetlag': 'N', 'msfsc1': 'N', 'mh_anx': 'N', 'mh_health': 'N', 'mh_mdd': 'N', 'education': 'N', 'income': 'N', 'age': 'N', 'orientation': 'N', 'race': 'N', 'sex': 'N', 'transgender': 'N'}
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Visualize the graph
plt.figure(figsize=(10,10))

colors = ['red'  if (y,x) in pc_graph.edges() else 'black' for (x,y) in pc_graph.edges()]
nx.draw_shell(pc_graph, with_labels=True, node_size=1000, font_size=12, arrowsize=50, node_color='w', edgecolors ='black', edge_color=colors)

# %%
gml = ''.join(nx.generate_gml(pc_graph))
model = CausalModel(
        data = df,
        treatment='Anxiety',
        outcome='Car_Accident',
        graph=gml)
model.view_model()

identified_estimand = model.identify_effect()
print(identified_estimand)

estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")
print("Causal Estimate is " + str(estimate.value))
# Out:
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Anxiety'] on outcome ['Car_Accident']
# INFO:dowhy.utils.plotting:Pygraphviz installation not found, falling back to networkx plotting. For better looking plots, consider installing pygraphviz. Note This requires both the Python pygraphviz package (``pip install pygraphviz``) and the shared system library (e.g. ``brew install graphviz`` or ``apt-get install graphviz``)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/classes/digraph.py:926, in DiGraph.successors(self, n)
#     925 try:
# --> 926     return iter(self._succ[n])
#     927 except KeyError as err:
#
# KeyError: 'Anxiety'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[15], line 9
#       2 model = CausalModel(
#       3         data = df,
#       4         treatment='Anxiety',
#       5         outcome='Car_Accident',
#       6         graph=gml)
#       7 model.view_model()
# ----> 9 identified_estimand = model.identify_effect()
#      10 print(identified_estimand)
#      12 estimate = model.estimate_effect(identified_estimand,
#      13         method_name="backdoor.linear_regression")
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_model.py:240, in CausalModel.identify_effect(self, estimand_type, method_name, proceed_when_unidentifiable, optimize_backdoor)
#     233 else:
#     234     identifier = AutoIdentifier(
#     235         estimand_type=estimand_type,
#     236         backdoor_adjustment=BackdoorAdjustment(method_name),
#     237         optimize_backdoor=optimize_backdoor,
#     238     )
# --> 240 identified_estimand = identifier.identify_effect(
#     241     graph=self._graph._graph,
#     242     action_nodes=self._treatment,
#     243     outcome_nodes=self._outcome,
#     244     observed_nodes=list(self._graph.get_all_nodes(include_unobserved=False)),
#     245 )
#     247 self.identifier = identifier
#     249 return identified_estimand
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_identifier/auto_identifier.py:101, in AutoIdentifier.identify_effect(self, graph, action_nodes, outcome_nodes, observed_nodes, conditional_node_names)
#      93 def identify_effect(
#      94     self,
#      95     graph: nx.DiGraph,
#    (...)
#      99     conditional_node_names: List[str] = None,
#     100 ):
# --> 101     estimand = identify_effect_auto(
#     102         graph,
#     103         action_nodes,
#     104         outcome_nodes,
#     105         observed_nodes,
#     106         self.estimand_type,
#     107         conditional_node_names,
#     108         self.backdoor_adjustment,
#     109         self.optimize_backdoor,
#     110         self.costs,
#     111     )
#     113     estimand.identifier = self
#     115     return estimand
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/causal_identifier/auto_identifier.py:169, in identify_effect_auto(graph, action_nodes, outcome_nodes, observed_nodes, estimand_type, conditional_node_names, backdoor_adjustment, optimize_backdoor, costs)
#     166 outcome_nodes = parse_state(outcome_nodes)
#     168 # First, check if there is a directed path from action to outcome
# --> 169 if not has_directed_path(graph, action_nodes, outcome_nodes):
#     170     logger.warn("No directed path from treatment to outcome. Causal Effect is zero.")
#     171     return IdentifiedEstimand(
#     172         None,
#     173         treatment_variable=action_nodes,
#     174         outcome_variable=outcome_nodes,
#     175         no_directed_path=True,
#     176     )
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/dowhy/graph.py:283, in has_directed_path(graph, action_nodes, outcome_nodes)
#     281 action_node_candidates = set()
#     282 for node in action_nodes:
# --> 283     outcome_node_candidates.update(nx.descendants(graph, node))
#     284 for node in outcome_nodes:
#     285     action_node_candidates.update(nx.ancestors(graph, node))
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 52:3, in argmap_descendants_49(G, source, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/algorithms/dag.py:73, in descendants(G, source)
#      39 @nx._dispatchable
#      40 def descendants(G, source):
#      41     """Returns all nodes reachable from `source` in `G`.
#      42
#      43     Parameters
#    (...)
#      71     ancestors
#      72     """
# ---> 73     return {child for parent, child in nx.bfs_edges(G, source)}
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/algorithms/dag.py:73, in <setcomp>(.0)
#      39 @nx._dispatchable
#      40 def descendants(G, source):
#      41     """Returns all nodes reachable from `source` in `G`.
#      42
#      43     Parameters
#    (...)
#      71     ancestors
#      72     """
# ---> 73     return {child for parent, child in nx.bfs_edges(G, source)}
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/algorithms/traversal/breadth_first_search.py:194, in bfs_edges(G, source, reverse, depth_limit, sort_neighbors)
#     190     yield from generic_bfs_edges(
#     191         G, source, lambda node: iter(sort_neighbors(successors(node))), depth_limit
#     192     )
#     193 else:
# --> 194     yield from generic_bfs_edges(G, source, successors, depth_limit)
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/algorithms/traversal/breadth_first_search.py:93, in generic_bfs_edges(G, source, neighbors, depth_limit)
#      91 n = len(G)
#      92 depth = 0
# ---> 93 next_parents_children = [(source, neighbors(source))]
#      94 while next_parents_children and depth < depth_limit:
#      95     this_parents_children = next_parents_children
#
# File ~/opt/miniconda3/envs/CDS/lib/python3.11/site-packages/networkx/classes/digraph.py:928, in DiGraph.successors(self, n)
#     926     return iter(self._succ[n])
#     927 except KeyError as err:
# --> 928     raise NetworkXError(f"The node {n} is not in the digraph.") from err
#
# NetworkXError: The node Anxiety is not in the digraph.

# %% [markdown]
# ### GES

# %%
from pgmpy.estimators import GES as pgmpy_ges
from pgmpy.estimators import ExhaustiveSearch, HillClimbSearch, BDeu, BIC


ges_graph_pgmpy = pgmpy_ges(df).estimate(scoring_method='bic-g')
colors = ['red'  if (y,x) in ges_graph_pgmpy.edges() else 'black' for (x,y) in ges_graph_pgmpy.edges()]

plt.figure(figsize=(12,12))
nx.draw_shell(ges_graph_pgmpy, with_labels=True, node_size=500, node_color='w', edgecolors ='black', edge_color=colors)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'subs_alc_1': 'N', 'subs_tob_1': 'N', 'socialjetlag': 'N', 'msfsc1': 'N', 'mh_anx': 'N', 'mh_health': 'N', 'mh_mdd': 'N', 'education': 'N', 'income': 'N', 'age': 'N', 'orientation': 'N', 'race': 'N', 'sex': 'N', 'transgender': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'subs_alc_1': 'N', 'subs_tob_1': 'N', 'socialjetlag': 'N', 'msfsc1': 'N', 'mh_anx': 'N', 'mh_health': 'N', 'mh_mdd': 'N', 'education': 'N', 'income': 'N', 'age': 'N', 'orientation': 'N', 'race': 'N', 'sex': 'N', 'transgender': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'subs_alc_1': 'N', 'subs_tob_1': 'N', 'socialjetlag': 'N', 'msfsc1': 'N', 'mh_anx': 'N', 'mh_health': 'N', 'mh_mdd': 'N', 'education': 'N', 'income': 'N', 'age': 'N', 'orientation': 'N', 'race': 'N', 'sex': 'N', 'transgender': 'N'}
